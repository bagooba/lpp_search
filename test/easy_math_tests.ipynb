# %%
import numpy as np

# %%
np.round([1/4, 1/3, 1/2, 2/1, 3/1, 4/1], 2)
# Out:
# array([0.25, 0.33, 0.5 , 2.  , 3.  , 4.  ])

# %%
factor = np.arange(2, 6)
check_multipls = sorted(list(1/factor)+list(factor))

check_multipls
# Out:
# [0.2, 0.25, 0.3333333333333333, 0.5, 2, 3, 4, 5]
